# %% [markdown]
# ## PyHPC Tutorial - NumPy, CuPy, JAX, mpi4py, & CUDA Kernels - 8 Hours
#
# ### Notebooks
#
# | # | Topic | Solution | Technologies |
# |---|-------|----------|--------------|
# | 00 | [NumPy Intro - ndarray Basics](../00__numpy_intro__ndarray_basics.ipynb) | [Click](../solutions/00__numpy_intro__ndarray_basics__SOLUTION.ipynb) | NumPy |
# | 01 | [NumPy to CuPy - ndarray Basics](../01__numpy_to_cupy__ndarray_basics.ipynb) | [Click](../solutions/01__numpy_to_cupy__ndarray_basics__SOLUTION.ipynb) | CuPy |
# | 02 | [Memory Spaces - Power Iteration](../02__memory_spaces__power_iteration.ipynb) | [Click](../solutions/02__memory_spaces__power_iteration__SOLUTION.ipynb) | CuPy |
# | 03 | [mpi4py - Collectives](../03__mpi4py__collectives.ipynb) | - | mpi4py |
# | 04 | [Intro - Libraries & Programming Models](../04__intro.ipynb) | - | NumPy |
# | 05 | [SWE Core - Reference Solver](../05__swe_core__reference_solver.ipynb) | - | NumPy |
# | 06 | [JAX - jit + lax.scan](../06__jax__lax_scan.ipynb) | [Click](../solutions/06__jax__lax_scan__SOLUTION.ipynb) | JAX |
# | 07 | [PyOMP - parallel for](../07__pyomp__parallel_for.ipynb) | [Click](../solutions/07__pyomp__parallel_for__SOLUTION.ipynb) | PyOMP |
# | 08 | [nanobind - C++ Kernel](../08__nanobind__cpp_kernel.ipynb) | [Click](../solutions/08__nanobind__cpp_kernel__SOLUTION.ipynb) | nanobind |
# | 09 | [CppJIT - GPU Thrust](../09__cppjit__gpu_thrust.ipynb) | [Click](../solutions/09__cppjit__gpu_thrust__SOLUTION.ipynb) | CppJIT, CUDA |
# | 10 | [Synthesis - Runtime & Throughput](../10__synthesis.ipynb) | - | - |
# | 11 | [Asynchrony - Power Iteration](../11__asynchrony__power_iteration.ipynb) | [Click](../solutions/11__asynchrony__power_iteration__SOLUTION.ipynb) | CuPy, Nsight Systems |
# | 12 | [Kernel Authoring - Copy](../12__kernel_authoring__copy.ipynb) | [Click](../solutions/12__kernel_authoring__copy__SOLUTION.ipynb) | Numba CUDA, Nsight Compute |
# | 13 | [Kernel Authoring - Book Histogram](../13__kernel_authoring__book_histogram.ipynb) | [Click](../solutions/13__kernel_authoring__book_histogram__SOLUTION.ipynb) | Numba CUDA, Nsight Compute |
#
# ### Materials
#
# | Docker Compose | Brev Instance | Brev Provider |
# |----------------|---------------|---------------|
# | [Link](https://github.com/NVIDIA/accelerated-computing-hub/blob/generated/main/tutorials/pyhpc/notebooks/syllabi/pyhpc__numpy_cupy_jax_mpi4py_kernels__8_hours__docker_compose.yml) | 4xL4, 2xL4, 2xL40S, or 1x L40S | Crusoe or any other with Flexible Ports |
#
# ### Introduction
#
# This tutorial tours the high-performance Python landscape, from array programming to custom GPU kernels and multi-process parallelism. We start with the NumPy and CuPy array model, move data deliberately between host and device, and distribute work across processes with mpi4py.
#
# We then solve one problem -- the 1D Shallow Water Equations -- five different ways, trading a NumPy baseline for JAX, PyOMP, nanobind, and CppJIT, and measure each against the others. We close by authoring and profiling our own CUDA kernels with Numba CUDA, Nsight Systems, and Nsight Compute.
#
# In this tutorial we will cover:
# - NumPy fundamentals and the `ndarray` memory model.
# - Accelerating array workflows on the GPU with CuPy, including memory spaces and asynchrony.
# - Distributed computing with mpi4py.
# - Programming models and Python/C++ interoperability: JAX, PyOMP, nanobind, and CppJIT.
# - Authoring and profiling custom CUDA kernels with Numba CUDA, Nsight Systems, and Nsight Compute.
#
# Attendees are expected to have general knowledge of HPC and Python programming. Some familiarity with NumPy and C/C++ is helpful but not required.

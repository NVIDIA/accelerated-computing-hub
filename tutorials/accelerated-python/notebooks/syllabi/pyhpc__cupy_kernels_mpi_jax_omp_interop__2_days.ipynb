# %% [markdown]
# ## PyHPC Tutorial - CuPy, Kernels, MPI, JAX, OMP, Interop - 2 Days
#
# ### Notebooks
#
# | # | Topic | Solution | Technologies |
# |---|-------|----------|--------------|
# | 01 | [NumPy](../fundamentals/01__numpy_intro__ndarray_basics.ipynb) | [Click](../fundamentals/solutions/01__numpy_intro__ndarray_basics__SOLUTION.ipynb) | NumPy |
# | 03 | [CuPy](../fundamentals/03__numpy_to_cupy__ndarray_basics.ipynb) | [Click](../fundamentals/solutions/03__numpy_to_cupy__ndarray_basics__SOLUTION.ipynb) | CuPy |
# | 05 | [Power Iteration - CuPy - Memory Spaces](../fundamentals/05__memory_spaces__power_iteration.ipynb) | [Click](../fundamentals/solutions/05__memory_spaces__power_iteration__SOLUTION.ipynb) | CuPy |
# | 06 | [Power Iteration - CuPy - Asynchrony](../fundamentals/06__asynchrony__power_iteration.ipynb) | [Click](../fundamentals/solutions/06__asynchrony__power_iteration__SOLUTION.ipynb) | CuPy, Nsight Systems |
# | 40 | [Copy - Kernel Authoring](../kernels/40__kernel_authoring__copy.ipynb) | [Click](../kernels/solutions/40__kernel_authoring__copy__SOLUTION.ipynb) | Numba CUDA, Nsight Compute |
# | 41 | [Book Histogram - Kernel Authoring](../kernels/41__kernel_authoring__book_histogram.ipynb) | [Click](../kernels/solutions/41__kernel_authoring__book_histogram__SOLUTION.ipynb) | Numba CUDA, Nsight Compute |
# | 62 | [mpi4py - Heat Equation](../distributed/62__mpi4py__heat_equation.ipynb) | [Click](../distributed/solutions/62__mpi4py__heat_equation__SOLUTION.ipynb) | mpi4py |
# | 80 | [C++ Interop](../applications/80__cpp_interop.ipynb) | [Click](../applications/solutions/80__cpp_interop__SOLUTION.ipynb) | ctypes, cffi, nanobind, CppJIT |
# | 81 | [SWE - Intro](../applications/81__swe__intro.ipynb) | - | NumPy |
# | 82 | [SWE - JAX](../applications/82__swe__jax.ipynb) | [Click](../applications/solutions/82__swe__jax__SOLUTION.ipynb) | JAX |
# | 83 | [SWE - PyOMP](../applications/83__swe__pyomp.ipynb) | [Click](../applications/solutions/83__swe__pyomp__SOLUTION.ipynb) | PyOMP |
# | 84 | [SWE - nanobind](../applications/84__swe__nanobind.ipynb) | [Click](../applications/solutions/84__swe__nanobind__SOLUTION.ipynb) | nanobind |
# | 85 | [SWE - CppJIT - CUB](../applications/85__swe__cppjit__cub.ipynb) | [Click](../applications/solutions/85__swe__cppjit__cub__SOLUTION.ipynb) | CppJIT, CUDA |
# | 86 | [SWE - mpi4py](../applications/86__swe__mpi4py.ipynb) | [Click](../applications/solutions/86__swe__mpi4py__SOLUTION.ipynb) | mpi4py |
# | 87 | [SWE - Synthesis](../applications/87__swe__synthesis.ipynb) | - | - |
#
# ### Materials
#
# | Docker Compose | Brev Instance | Brev Provider |
# |----------------|---------------|---------------|
# | [Link](https://github.com/NVIDIA/accelerated-computing-hub/blob/generated/main/tutorials/accelerated-python/notebooks/syllabi/pyhpc__cupy_kernels_mpi_jax_omp_interop__2_days__docker_compose.yml) | L40S, L4, or T4 | Crusoe or any other with Flexible Ports; host driver must support CUDA 13 |
#
# ### Introduction
#
# This tutorial tours the high-performance Python landscape, from array programming to custom GPU kernels and multi-process parallelism. We start with the NumPy and CuPy array model, move data deliberately between host and device, profile asynchronous execution, and author custom CUDA kernels.
#
# We then distribute work across processes with mpi4py and solve one problem -- the 1D Shallow Water Equations -- six different ways: a NumPy baseline and five alternatives using JAX, PyOMP, nanobind, CppJIT, and mpi4py. We measure each implementation against the others.
#
# In this tutorial we will cover:
# - NumPy fundamentals and the `ndarray` memory model.
# - Accelerating array workflows on the GPU with CuPy, including memory spaces and asynchrony.
# - Authoring and profiling custom CUDA kernels with Numba CUDA, Nsight Systems, and Nsight Compute.
# - Distributed computing with mpi4py.
# - Programming models and Python/C++ interoperability: JAX, PyOMP, nanobind, and CppJIT.
#
# Attendees are expected to have general knowledge of HPC and Python programming. Some familiarity with NumPy and C/C++ is helpful but not required.

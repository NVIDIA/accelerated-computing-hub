# %% [markdown]
# ## Exercise - cuDF - NYC Parking Violations

# %% [markdown]
# We've learned how to work with numeric data using CuPy. But many applications, in data science and machine learning involve other kinds of data, like dates and strings.
#
# [cuDF](https://docs.rapids.ai/api/cudf/stable/) is a DataFrame library for loading, joining, aggregating, filtering, and otherwise manipulating data. It offers both a [Pandas](https://docs.rapids.ai/api/cudf/stable/cudf_pandas/) and a [Polars](https://docs.rapids.ai/api/cudf/stable/cudf_polars/) API.

# %% [markdown]
# ### A quick Pandas introduction

# %%
import pandas as pd

# %% [markdown]
# #### Series and DataFrame objects

# %%
s = pd.Series([1, 2, 3])
s
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
print("Max value: ", s.max())
print("Mean value: ", s.mean())
# Out:
# Max value:  3
# Mean value:  2.0

# %%
s = pd.Series(["one", "two", "three"])

# %%
print("Max value: ", s.max())
# Out:
# Max value:  two

# %%
df = pd.DataFrame({
    "a" : [1, 2, 1, 3, 2],
    "b" : [1, 4, 7, 2, 0],
    "c" : [3, 3, 3, 4, 5]
}, index = [1, 2, 3, 4, 5])
df
# Out:
#    a  b  c
# 1  1  1  3
# 2  2  4  3
# 3  1  7  3
# 4  3  2  4
# 5  2  0  5

# %%
df.index
# Out:
# Index([1, 2, 3, 4, 5], dtype='int64')

# %%
df.columns
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %% [markdown]
# #### Selecting and filtering data

# %%
df.head(2)
# Out:
#    a  b  c
# 1  1  1  3
# 2  2  4  3

# %%
df.tail(2)
# Out:
#    a  b  c
# 4  3  2  4
# 5  2  0  5

# %%
df["a"]
# Out:
# 1    1
# 2    2
# 3    1
# 4    3
# 5    2
# Name: a, dtype: int64

# %%
df[["b", "c"]]
# Out:
#    b  c
# 1  1  3
# 2  4  3
# 3  7  3
# 4  2  4
# 5  0  5

# %%
df.iloc[0:2]
# Out:
#    a  b  c
# 1  1  1  3
# 2  2  4  3

# %%
df.iloc[0, 1:3]
# Out:
# b    1
# c    3
# Name: 1, dtype: int64

# %%
df.loc[2:3, "b":"c"]
# Out:
#    b  c
# 2  4  3
# 3  7  3

# %%
df[df['a'] > 1]
# Out:
#    a  b  c
# 2  2  4  3
# 4  3  2  4
# 5  2  0  5

# %% [markdown]
# #### Sorting

# %%
df.sort_values("a")
# Out:
#    a  b  c
# 1  1  1  3
# 3  1  7  3
# 2  2  4  3
# 5  2  0  5
# 4  3  2  4

# %% [markdown]
# #### Summarizing Data

# %%
df.sum()
# Out:
# a     9
# b    14
# c    18
# dtype: int64

# %%
df["a"].mean()
# Out:
# np.float64(1.8)

# %% [markdown]
# #### Grouped aggregations

# %%
df["a"].value_counts()
# Out:
# a
# 1    2
# 2    2
# 3    1
# Name: count, dtype: int64

# %%
df["c"].value_counts()
# Out:
# c
# 3    3
# 4    1
# 5    1
# Name: count, dtype: int64

# %%
df.groupby("a").mean()
# Out:
#      b    c
# a
# 1  4.0  3.0
# 2  2.0  4.0
# 3  2.0  4.0

# %%
df.groupby("c").count()
# Out:
#    a  b
# c
# 3  3  3
# 4  1  1
# 5  1  1

# %%
df.groupby("a").agg({"b": ["min", "mean"], "c": ["max"]})
# Out:
#     b        c
#   min mean max
# a
# 1   1  4.0   3
# 2   0  2.0   5
# 3   2  2.0   4

# %% [markdown]
# #### String operations

# %%
df["d"] = ["mario", "luigi", "yoshi", "peach", "toad"]
df
# Out:
#    a  b  c      d
# 1  1  1  3  mario
# 2  2  4  3  luigi
# 3  1  7  3  yoshi
# 4  3  2  4  peach
# 5  2  0  5   toad

# %%
df["d"].str.upper()
# Out:
# 1    MARIO
# 2    LUIGI
# 3    YOSHI
# 4    PEACH
# 5     TOAD
# Name: d, dtype: object

# %% [markdown]
# #### Time Series

# %%
import numpy as np

date_df = pd.DataFrame()
date_df["date"] = pd.date_range("11/20/2018", periods=72, freq="D")
date_df["value"] = np.random.sample(len(date_df))
date_df
# Out:
#          date     value
# 0  2018-11-20  0.453224
# 1  2018-11-21  0.127411
# 2  2018-11-22  0.439165
# 3  2018-11-23  0.694320
# 4  2018-11-24  0.979057
# ..        ...       ...
# 67 2019-01-26  0.326564
# 68 2019-01-27  0.303860
# 69 2019-01-28  0.936735
# 70 2019-01-29  0.307780
# 71 2019-01-30  0.353858
#
# [72 rows x 2 columns]

# %%
date_df[date_df["date"] < "2018-11-24"]
# Out:
#         date     value
# 0 2018-11-20  0.453224
# 1 2018-11-21  0.127411
# 2 2018-11-22  0.439165
# 3 2018-11-23  0.694320

# %%
date_df["year"] = date_df["date"].dt.year
date_df
# Out:
#          date     value  year
# 0  2018-11-20  0.453224  2018
# 1  2018-11-21  0.127411  2018
# 2  2018-11-22  0.439165  2018
# 3  2018-11-23  0.694320  2018
# 4  2018-11-24  0.979057  2018
# ..        ...       ...   ...
# 67 2019-01-26  0.326564  2019
# 68 2019-01-27  0.303860  2019
# 69 2019-01-28  0.936735  2019
# 70 2019-01-29  0.307780  2019
# 71 2019-01-30  0.353858  2019
#
# [72 rows x 3 columns]

# %% [markdown]
# #### User-defined operations

# %%
def add_ten(x):
    return x + 10

df["a"] = df["a"].apply(add_ten)
df
# Out:
#     a  b  c      d
# 1  11  1  3  mario
# 2  12  4  3  luigi
# 3  11  7  3  yoshi
# 4  13  2  4  peach
# 5  12  0  5   toad

# %% [markdown]
# ### Now let's do the same thing with cuDF

# %%
import cudf

# %%
df = cudf.DataFrame({
    "a" : [1, 2, 1, 3, 2],
    "b" : [1, 4, 7, 2, 0],
    "c" : [1, 1, 8, 2, 9]
}, index = [1, 2, 3, 4, 5])
df
# Out:
#    a  b  c
# 1  1  1  1
# 2  2  4  1
# 3  1  7  8
# 4  3  2  2
# 5  2  0  9

# %%
type(df)
# Out:
# cudf.core.dataframe.DataFrame

# %%
df.loc[2:3, "b":"c"]
# Out:
#    b  c
# 2  4  1
# 3  7  8

# %%
df.groupby("a").agg({"b": ["min", "mean"], "c": ["max"]})
# Out:
#     b        c
#   min mean max
# a
# 2   0  2.0   9
# 1   1  4.0   8
# 3   2  2.0   2

# %% [markdown]
# Some things are different though!

# %%
import numpy as np

date_df = cudf.DataFrame()
date_df["date"] = cudf.date_range("11/20/2018", periods=72, freq="D")
date_df["value"] = np.random.sample(len(date_df))
date_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 4
#       1 import numpy as np
#       3 date_df = cudf.DataFrame()
# ----> 4 date_df["date"] = cudf.date_range("11/20/2018", periods=72, freq="D")
#       5 date_df["value"] = np.random.sample(len(date_df))
#       6 date_df
#
# File /usr/local/python/3.13.5/lib/python3.13/site-packages/cudf/core/tools/datetimes.py:900, in date_range(start, end, periods, freq, tz, normalize, name, inclusive, unit)
#     895     start = (
#     896         pd.Timestamp(end)
#     897         - (periods - 1) * offset._maybe_as_fast_pandas_offset()
#     898     ).to_numpy()
#     899 elif end is None:
# --> 900     start = dtype.type(start, unit)
#     901 elif periods is None:
#     902     # When `periods` is unspecified, its upper bound estimated by
#     903     # dividing the number of nanoseconds between two timestamps with
#     904     # the lower bound of `freq` in nanoseconds. While the final result
#     905     # may contain extra elements that exceeds `end`, they are trimmed
#     906     # as a post processing step. [1]
#     907     _periods_not_specified = True
#
# ValueError: Error parsing datetime string "11/20/2018" at position 2

# %% [markdown]
# Unlike Pandas, cuDF does not (yet) have the ability to interpret the date `"11/20/2018"`, instead use the more standard `"2018-11-20"`:

# %%
date_df = cudf.DataFrame()
date_df["date"] = cudf.date_range("2018-11-20", periods=72, freq="D")
date_df["value"] = np.random.sample(len(date_df))
date_df
# Out:
#          date     value
# 0  2018-11-20  0.896092
# 1  2018-11-21  0.524976
# 2  2018-11-22  0.375614
# 3  2018-11-23  0.950067
# 4  2018-11-24  0.291348
# ..        ...       ...
# 67 2019-01-26  0.099531
# 68 2019-01-27  0.372808
# 69 2019-01-28  0.379842
# 70 2019-01-29  0.164194
# 71 2019-01-30  0.577193
#
# [72 rows x 2 columns]

# %%
date_df[date_df["date"] < "2018-11-24"]
# Out:
#         date     value
# 0 2018-11-20  0.896092
# 1 2018-11-21  0.524976
# 2 2018-11-22  0.375614
# 3 2018-11-23  0.950067

# %%
def add_ten(x):
    return x + 10

df["a"] = df["a"].apply(add_ten)
df
# Out:
# ---------------------------------------------------------------------------
# nvJitLinkError                            Traceback (most recent call last)
# File /usr/local/python/3.13.5/lib/python3.13/site-packages/cudf/core/indexed_frame.py:3515, in IndexedFrame._apply(self, func, kernel_class, *args, **kwargs)
#    3514     kr = kernel_class(self, func, args)
# -> 3515     kernel, retty = kr.get_kernel()
#    3516 except Exception as e:
#
# File /usr/local/python/3.13.5/lib/python3.13/site-packages/cudf/core/udf/udf_kernel_base.py:167, in ApplyKernelBase.get_kernel(self)
#     166 def get_kernel(self):
# --> 167     return self._compile_or_get_kernel()
#
# File /usr/local/python/3.13.5/lib/python3.13/site-packages/cudf/core/udf/udf_kernel_base.py:184, in ApplyKernelBase._compile_or_get_kernel(self)
#     182     return kernel, masked_or_scalar
# --> 184 kernel, scalar_return_type = self.compile_kernel()
#     186 np_return_type = (
#     187     numpy_support.as_dtype(scalar_return_type)
#     188     if scalar_return_type.is_internal
#     189     else scalar_return_type.np_dtype
#     190 )
#
# File /usr/local/python/3.13.5/lib/python3.13/site-packages/cudf/core/udf/udf_kernel_base.py:145, in ApplyKernelBase.compile_kernel(self)
#     144 kernel_string = self._get_kernel_string()
# --> 145 kernel = self.compile_kernel_string(
#     146     kernel_string, nrt=capture_nrt_usage.use_nrt
#     147 )
#     149 return kernel, return_type
#
# File /usr/local/python/3.13.5/lib/python3.13/site-packages/cudf/core/udf/udf_kernel_base.py:159, in ApplyKernelBase.compile_kernel_string(self, kernel_string, nrt)
#     158 with ctx:
# --> 159     kernel = cuda.jit(
#     160         self.sig,
#     161         link=[UDF_SHIM_FILE],
#     162         extensions=[str_view_arg_handler],
#     163     )(_kernel)
#     164 return kernel
#
# File /usr/local/python/3.13.5/lib/python3.13/site-packages/numba_cuda/numba/cuda/decorators.py:207, in jit.<locals>._jit(func)
#     206     else:
# --> 207         disp.compile(argtypes)
#     209 disp._specialized = specialized
#
# File /usr/local/python/3.13.5/lib/python3.13/site-packages/numba/core/compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      34 with self:
# ---> 35     return func(*args, **kwargs)
#
# File /usr/local/python/3.13.5/lib/python3.13/site-packages/numba_cuda/numba/cuda/dispatcher.py:1298, in CUDADispatcher.compile(self, sig)
#    1297 # We call bind to force codegen, so that there is a cubin to cache
# -> 1298 kernel.bind()
#    1299 self._cache.save_overload(sig, kernel)
#
# File /usr/local/python/3.13.5/lib/python3.13/site-packages/numba_cuda/numba/cuda/dispatcher.py:331, in _Kernel.bind(self)
#     328 """
#     329 Force binding to current CUDA context
#     330 """
# --> 331 cufunc = self._codelibrary.get_cufunc()
#     333 self.initialize_once(cufunc.module)
#
# File /usr/local/python/3.13.5/lib/python3.13/site-packages/numba_cuda/numba/cuda/codegen.py:339, in CUDACodeLibrary.get_cufunc(self)
#     338     return cufunc
# --> 339 cubin = self.get_cubin(cc=device.compute_capability)
#     340 module = ctx.create_module_image(
#     341     cubin, self._setup_functions, self._teardown_functions
#     342 )
#
# File /usr/local/python/3.13.5/lib/python3.13/site-packages/numba_cuda/numba/cuda/codegen.py:318, in CUDACodeLibrary.get_cubin(self, cc)
#     317 self._link_all(linker, cc, ignore_nonlto=False)
# --> 318 cubin = linker.complete()
#     320 self._cubin_cache[cc] = cubin
#
# File /usr/local/python/3.13.5/lib/python3.13/site-packages/numba_cuda/numba/cuda/cudadrv/driver.py:3060, in _Linker.complete(self)
#    3059 def complete(self):
# -> 3060     self.linker = Linker(*self._object_codes, options=self.options)
#    3061     result = self.linker.link("cubin")
#
# File /usr/local/python/3.13.5/lib/python3.13/site-packages/cuda/core/experimental/_linker.py:394, in Linker.__init__(self, options, *object_codes)
#     393 assert_type(code, ObjectCode)
# --> 394 self._add_code_object(code)
#
# File /usr/local/python/3.13.5/lib/python3.13/site-packages/cuda/core/experimental/_linker.py:402, in Linker._add_code_object(self, object_code)
#     401 if _nvjitlink:
# --> 402     _nvjitlink.add_data(
#     403         self._mnff.handle,
#     404         self._input_type_from_code_type(object_code._code_type),
#     405         data,
#     406         len(data),
#     407         name_str,
#     408     )
#     409 else:
#
# File /usr/local/python/3.13.5/lib/python3.13/site-packages/cuda/bindings/nvjitlink.pyx:124, in cuda.bindings.nvjitlink.add_data()
#
# File /usr/local/python/3.13.5/lib/python3.13/site-packages/cuda/bindings/nvjitlink.pyx:143, in cuda.bindings.nvjitlink.add_data()
#
# File /usr/local/python/3.13.5/lib/python3.13/site-packages/cuda/bindings/nvjitlink.pyx:75, in cuda.bindings.nvjitlink.check_status()
#
# nvJitLinkError: ERROR_INTERNAL (6)
# Linker error log: ERROR 4 in nvvmAddNVVMContainerToProgram, may need newer version of nvJitLink library
#
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 4
#       1 def add_ten(x):
#       2     return x + 10
# ----> 4 df["a"] = df["a"].apply(add_ten)
#       5 df
#
# File /usr/local/python/3.13.5/lib/python3.13/site-packages/cudf/utils/performance_tracking.py:51, in _performance_tracking.<locals>.wrapper(*args, **kwargs)
#      43 if nvtx.enabled():
#      44     stack.enter_context(
#      45         nvtx.annotate(
#      46             message=func.__qualname__,
#    (...)     49         )
#      50     )
# ---> 51 return func(*args, **kwargs)
#
# File /usr/local/python/3.13.5/lib/python3.13/site-packages/cudf/core/series.py:2566, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    2563 elif by_row != "compat":
#    2564     raise NotImplementedError("by_row is currently not supported.")
# -> 2566 result = self._apply(func, SeriesApplyKernel, *args, **kwargs)
#    2567 result.name = self.name
#    2568 return result
#
# File /usr/local/python/3.13.5/lib/python3.13/contextlib.py:85, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      82 @wraps(func)
#      83 def inner(*args, **kwds):
#      84     with self._recreate_cm():
# ---> 85         return func(*args, **kwds)
#
# File /usr/local/python/3.13.5/lib/python3.13/site-packages/cudf/utils/performance_tracking.py:51, in _performance_tracking.<locals>.wrapper(*args, **kwargs)
#      43 if nvtx.enabled():
#      44     stack.enter_context(
#      45         nvtx.annotate(
#      46             message=func.__qualname__,
#    (...)     49         )
#      50     )
# ---> 51 return func(*args, **kwargs)
#
# File /usr/local/python/3.13.5/lib/python3.13/site-packages/cudf/core/indexed_frame.py:3517, in IndexedFrame._apply(self, func, kernel_class, *args, **kwargs)
#    3515     kernel, retty = kr.get_kernel()
#    3516 except Exception as e:
# -> 3517     raise ValueError(
#    3518         "user defined function compilation failed."
#    3519     ) from e
#    3521 # Mask and data column preallocated
#    3522 ans_col = _return_arr_from_dtype(retty, len(self))
#
# ValueError: user defined function compilation failed.

# %% [markdown]
# ### Exercise: Working With Real Data
#
# In this exercise, you'll use Pandas to analyze some real-world data, and then repeat the analysis with cuDF.
#
# #### Download the data
#
# The data we'll be working with is the [Parking Violations Issued - Fiscal Year 2022](https://data.cityofnewyork.us/City-Government/Parking-Violations-Issued-Fiscal-Year-2022/7mxj-7a6y) dataset from NYC Open Data.
#
# We're downloading a copy of this dataset from an s3 bucket hosted by NVIDIA to provide faster download speeds. We'll start by downloading the data. This should take about 30 seconds.
#
# #### Data License and Terms
# As this dataset originates from the NYC Open Data Portal, it's governed by their license and terms of use.
#
# ###### Are there restrictions on how I can use Open Data?
#
# > Open Data belongs to all New Yorkers. There are no restrictions on the use of Open Data. Refer to Terms of Use for more information.
#
# ##### [Terms of Use](https://opendata.cityofnewyork.us/overview/#termsofuse)
#
# > By accessing datasets and feeds available through NYC Open Data, the user agrees to all of the Terms of Use of NYC.gov as well as the Privacy Policy for NYC.gov. The user also agrees to any additional terms of use defined by the agencies, bureaus, and offices providing data. Public data sets made available on NYC Open Data are provided for informational purposes. The City does not warranty the completeness, accuracy, content, or fitness for any particular purpose or use of any public data set made available on NYC Open Data, nor are any such warranties to be implied or inferred with respect to the public data sets furnished therein.
#
# > The City is not liable for any deficiencies in the completeness, accuracy, content, or fitness for any particular purpose or use of any public data set, or application utilizing such data set, provided by any third party.
#
# > Submitting City Agencies are the authoritative source of data available on NYC Open Data. These entities are responsible for data quality and retain version control of data sets and feeds accessed on the Site. Data may be updated, corrected, or refreshed at any time.

# %%
# !wget -nc https://data.rapids.ai/datasets/nyc_parking/nyc_parking_violations_2022.parquet -O nyc_parking_violations_2022.parquet

# %%
import pandas as pd

data = pd.read_parquet("nyc_parking_violations_2022.parquet")
data.head()

# %% [markdown]
# #### Task 1

# %% [markdown]
# This dataset is relatively large, with lots of columns.
#
# * How many columns are there?
# * Extract a subset of the data with just the following columns:
#   * `"Registration State"`
#   * `"Violation Description"`
#   * `"Vehicle Body Type"`
#   * `"Issue Date"`

# %% [markdown]
# #### Task 2

# %% [markdown]
# For vehicles with body type `"TAXI"`, what is the number of vehicles from each state?

# %% [markdown]
# #### Task 3
#
# Now, repeat the analysis (starting from `read_parquet`) using cuDF. How much faster is it compared to Pandas? To measure the execution of a cell in Jupyter Notebook, you can add the line `%%time` at the top of a cell. For example:
#
# ```python
# %%time
#
# import cudf
# data = cudf.read_parquet("nyc_parking_violations_2022.parquet")
# data.head()
# ````

# %% [markdown]
# ### Resources

# %% [markdown]
# * `cudf.pandas` docs: https://docs.rapids.ai/api/cudf/stable/cudf_pandas/
# * cuDF documentation: https://docs.rapids.ai/api/cudf/stable
# * cuDF API reference: https://docs.rapids.ai/api/cudf/stable/user_guide/api_docs/
